# %%
from yargy import rule, Parser
from yargy.predicates import gram, dictionary, type, eq
from yargy.interpretation import fact, attribute
from yargy import Parser, rule, or_
from yargy.pipelines import morph_pipeline
from dataclasses import dataclass
from typing import Optional
from yargy.relations import gnc_relation

# %%
# Определение структур фактов
@dataclass
class Entry:
    name: str
    birth_date: Optional[str]
    birth_place: Optional[str]

# %%
Entry = fact(
    'Entry',
    ['Name', 'BirthDate', 'BirthPlace']
)

# %%
Name = fact(
    'Name',
    ['first', 'last', 'middle']
)

BirthDate = fact(
    'BirthDate',
    ['date']
)

BirthPlace = fact(
    'BirthPlace',
    ['place']
)

# %%
# Правила для имени, даты рождения и места рождения
NAME = rule(
    gram("Name").interpretation(
        Name.first.inflected()
    ),
    gram("Surn").interpretation(
        Name.last.inflected()
    ),
    gram('Patr').optional().interpretation(
        Name.middle.normalized()
    )
).interpretation(
    Name
)

BORN_VERB = morph_pipeline([
    "родился",
    "родилась",
    "родился в", 
    "родилась в", 
    "появился на свет в",
    "появилась на свет в",
    "родился в городе"
])

BORN_YEAR_WORD = morph_pipeline([
    "родился",
    "родилась",
    "родился в", 
    "родилась в", 
    "появился на свет в",
    "появилась на свет в",
    "родился в городе",
    "в",
    "году"
])

# %%
from yargy import rule, and_, or_, Parser
from yargy.predicates import gte, lte, dictionary, normalized
from yargy.interpretation import fact

# Создаем факт BirthDate с атрибутами day, month и year
BirthDate = fact(
    'BirthDate',
    ['day', 'month', 'year']
)

MONTHS = {
    'январь',
    'февраль',
    'март',
    'апрель',
    'май',
    'июнь',
    'июль',
    'август',
    'сентябрь',
    'октябрь',
    'ноябрь',
    'декабрь'
}

DAY = and_(
    gte(1),
    lte(31)
)

MONTH = dictionary(MONTHS)

YEAR = and_(
    gte(1),
    lte(2023)
)

DATE_TEXT = rule(
    DAY.interpretation(
        BirthDate.day
    ).optional(),
    MONTH.interpretation(
        BirthDate.month
    ).optional(),
    YEAR.interpretation(
        BirthDate.year
    )
).interpretation(
    BirthDate
)

DATE_DDMMYYYY = rule(
    DAY.interpretation(
        BirthDate.day
    ).optional(),
    '.',
    DAY.interpretation(
        BirthDate.month
    ).optional(),
    '.',
    YEAR.interpretation(
        BirthDate.year
    )
).interpretation(
    BirthDate
)

# %%
BIRTH_DATE = or_(
    DATE_DDMMYYYY,
    DATE_TEXT
).interpretation(
    BirthDate
)

BIRTH_PLACE = rule(
    gram('Geox').interpretation(
        BirthPlace.place.normalized()
    )
).interpretation(
    BirthPlace
)

# %%
# # Связь между элементами правил
# gnc = gnc_relation()
# ExtendedName = Name.match(gnc)
# BirthDate = BirthDate.match(gnc)
# BirthPlace = BirthPlace.match(gnc)

# %%
# Комбинированное правило
S = rule(
    NAME.interpretation(
        Entry.Name
    ),
    BORN_VERB,
    BIRTH_PLACE.optional().interpretation(
        Entry.BirthPlace
    ),
    BORN_YEAR_WORD.optional(),
    BIRTH_DATE.optional().interpretation(
        Entry.BirthDate
    )
).interpretation(
    Entry
)

# %%
# Создание и применение парсера
parser = Parser(S)

# %%
try:
    with open('/Users/kseniiatokareva/Documents/nlp-2023/news.txt', 'r', encoding='utf-8') as file:
        for line in file:
            for match in parser.findall(line):
                if(match.fact.BirthDate or match.fact.BirthPlace):
                    print(match.fact)
                name_fact = match.fact.Name
                birth_date_fact = match.fact.BirthDate
                birth_place_fact = match.fact.BirthPlace

                entry = Entry(
                    Name=name_fact,
                    BirthDate=birth_date_fact if birth_date_fact else None,
                    BirthPlace=birth_place_fact if birth_place_fact else None
                )

                # print(entry)
                
                with open('/Users/kseniiatokareva/Documents/nlp-2023/output2.txt', 'a', encoding='utf-8') as f:
                    f.write(str(entry) + '\n')

except Exception as e:
    print(f"Ошибка: {e}")
# Out:
# Entry(Name=Name(first='андрей', last='курносенко', middle=None), BirthDate=None, BirthPlace=BirthPlace(place='севастополь'))
# Entry(Name=Name(first='яковлевюрий', last='яковлев', middle=None), BirthDate=BirthDate(day=None, month=None, year='1928'), BirthPlace=BirthPlace(place='москва'))
# Entry(Name=Name(first='николай', last='караченцов', middle=None), BirthDate=BirthDate(day='27', month='октября', year='1944'), BirthPlace=None)
# Entry(Name=Name(first='сергей', last='довлатов', middle=None), BirthDate=BirthDate(day=None, month=None, year='1941'), BirthPlace=None)
# Entry(Name=Name(first='аня', last='титов', middle=None), BirthDate=BirthDate(day=None, month=None, year='1984'), BirthPlace=None)
# Entry(Name=Name(first='игорь', last='доценко', middle=None), BirthDate=BirthDate(day=None, month=None, year='1953'), BirthPlace=None)
# Entry(Name=Name(first='андрей', last='сердюков', middle=None), BirthDate=BirthDate(day=None, month=None, year='1962'), BirthPlace=None)
# Entry(Name=Name(first='анатолий', last='сморгонский', middle=None), BirthDate=BirthDate(day=None, month=None, year='1979'), BirthPlace=None)
# Entry(Name=Name(first='инна', last='лиснянская', middle=None), BirthDate=BirthDate(day=None, month=None, year='1928'), BirthPlace=BirthPlace(place='баку'))
# Entry(Name=Name(first='эрик', last='хобсбаум', middle=None), BirthDate=BirthDate(day=None, month=None, year='1917'), BirthPlace=None)
# Entry(Name=Name(first='татьяна', last='самойлов', middle=None), BirthDate=BirthDate(day='4', month='мая', year='1934'), BirthPlace=None)
# Entry(Name=Name(first='владимир', last='высоцкий', middle=None), BirthDate=BirthDate(day=None, month=None, year='1938'), BirthPlace=BirthPlace(place='москва'))
# Entry(Name=Name(first='борис', last='васильев', middle=None), BirthDate=BirthDate(day='21', month='мая', year='1924'), BirthPlace=None)
# Entry(Name=Name(first='расул', last='гамзатов', middle=None), BirthDate=BirthDate(day=None, month=None, year='1923'), BirthPlace=None)
# Entry(Name=Name(first='евгений', last='гришковец', middle=None), BirthDate=BirthDate(day=None, month=None, year='1967'), BirthPlace=None)
# Entry(Name=Name(first='лев', last='дуров', middle=None), BirthDate=BirthDate(day='23', month='декабря', year='1931'), BirthPlace=None)
# Entry(Name=Name(first='зинаида', last='серебрякова', middle=None), BirthDate=BirthDate(day='28', month='июня', year='1913'), BirthPlace=None)
# Entry(Name=Name(first='игорь', last='кваша', middle=None), BirthDate=BirthDate(day=None, month=None, year='1933'), BirthPlace=BirthPlace(place='москва'))
# Entry(Name=Name(first='полина', last='жеребцов', middle=None), BirthDate=BirthDate(day=None, month=None, year='1985'), BirthPlace=BirthPlace(place='грозный'))
# Entry(Name=Name(first='юрий', last='трофимов', middle=None), BirthDate=BirthDate(day=None, month=None, year='1940'), BirthPlace=None)
# Entry(Name=Name(first='алексей', last='ремизов', middle=None), BirthDate=BirthDate(day=None, month=None, year='1877'), BirthPlace=BirthPlace(place='москва'))
